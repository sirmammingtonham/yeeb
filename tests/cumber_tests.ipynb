# %%
import cv2
import numpy as np

# %%
img = cv2.imread('test3.jpeg')
res = img.copy()
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# %%
lower_green = np.array([25,50,50])
upper_green = np.array([80,255,255]) # took too damn long to find these values
mask = cv2.inRange(hsv, lower_green, upper_green)

# %%
x_dim, y_dim = mask.shape
cumbered = np.argwhere(mask>0) # flatten and return array where mask is true
# randomized = np.random.choice((mask>0).flatten(), len(mask>0)*2//10)

# %%
# res[mask>0]=(0,0,0)

# %%
mask = mask/255
mask = mask.astype(np.bool)
# res[:,:,:3][mask] = [0, 0, 0]
hmm = np.argwhere(mask)
hmm[len(hmm)*5//10]
# Out:
# array([416, 969], dtype=int64)

# %%
h = cv2.rectangle(res, (hmm[0][1], hmm[0][0]), (hmm[len(hmm)*5//10][1], hmm[len(hmm)*5//10][0]), (0,0,0), -1)

# %%
cv2.imshow('image', img)
cv2.imshow('Result', res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import matplotlib.pyplot as plt
import cvlib as cv
from cvlib.object_detection import draw_bbox

# %%
im = cv2.imread('test3.jpeg')
bbox, label, conf = cv.detect_common_objects(im)
output_image = draw_bbox(im, bbox, label, conf)
plt.imshow(output_image)
plt.show()

# %% [markdown]
# bruh i cant find any cucumber image detection datasets...........

# %%
import cv2
import numpy as np

# %%
def viewImage(image):
    cv2.namedWindow('Display', cv2.WINDOW_NORMAL)
    cv2.imshow('Display', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
image = cv2.imread('test1.jpeg')
hsv_img = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
green_low = np.array([45 , 100, 50])
green_high = np.array([95, 255, 255])
curr_mask = cv2.inRange(hsv_img, green_low, green_high)
hsv_img[curr_mask > 0] = ([0,0,255])
viewImage(hsv_img)

# %%
## converting the HSV image to Gray inorder to be able to apply 
## contouring
RGB_again = cv2.cvtColor(hsv_img, cv2.COLOR_HSV2RGB)
gray = cv2.cvtColor(RGB_again, cv2.COLOR_RGB2GRAY)
viewImage(gray) ## 3

# %%
ret, threshold = cv2.threshold(gray, 90, 255, 0)
viewImage(threshold) ## 4

# %%
# contours, hierarchy =  cv2.findContours(threshold,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
# cv2.drawContours(image, contours, -1, (0, 0, 255), 3)
viewImage(image) ## 5
